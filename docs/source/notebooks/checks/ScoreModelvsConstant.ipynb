# %%
from scifit.solvers import linear

# %%
line = linear.LinearFitSolver()

# %%
data = line.synthetic_dataset(sigma=0.15)

# %%
sol = line.fit(data)

# %%
axe = line.plot_fit()

# %%
const = linear.ConstantFitSolver()

# %%
sol2 = const.fit(data)

# %%
axe = const.plot_fit()
