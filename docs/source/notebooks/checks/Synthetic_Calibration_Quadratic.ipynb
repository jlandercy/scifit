# %%
from scifit.solvers import linear, scientific, specials

# %%
solver = linear.ParabolicFitSolver()

# %%
data = solver.synthetic_dataset(sigma=0.015, xmin=1e-4, xmax=1e-2, parameters=[5.63e4, 1.21e3, 2.38], scale_mode="auto")

# %%
data.sample(5)
# Out:
#           x0          y        sy       yref    ynoise
# id
# 12  0.003855   8.012509  0.132063   7.881509  0.131000
# 26  0.008634  16.963153  0.132063  17.025131 -0.061978
# 15  0.004879   9.580218  0.132063   9.624337 -0.044119
# 23  0.007610  14.874808  0.132063  14.849264  0.025544
# 5   0.001466   4.179030  0.132063   4.274194 -0.095163

# %%
_ = solver.load(data)

# %%
solution = solver.fit()

# %%
axe = solver.plot_fit()

# %%
axe = solver.plot_chi_square()

# %%
final = solver.dataset()

# %%
solver.dump("data/parabolic.csv", final, summary=False)
