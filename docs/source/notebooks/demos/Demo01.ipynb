# %%
from scifit.solvers import scientific

# %%
solver = scientific.MichaelisMentenKineticFitSolver()

# %%
data = solver.load("../docs/data/MichaelisMentenKinetic.csv")

# %%
solution = solver.fit(data)

# %%
axe = solver.plot_fit()

# %%
axe = solver.plot_chi_square()

# %%
axe = solver.plot_kolmogorov()

# %%
axe = solver.plot_loss(log_loss=True)

# %%
axe = solver.plot_loss(log_loss=True, surface=True, resolution=100)
